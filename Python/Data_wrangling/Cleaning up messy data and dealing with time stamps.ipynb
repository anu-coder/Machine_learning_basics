# %% [markdown]
# ### Benefits of inline matplotlib:
#
# 1. Sets the backend of matplotlib to inline backend
# 2. The plots are displayed inline within jupyter notebook
# 3. The resulting plots should also get stored in the document
#
# Lets check after this notebook

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Make the graphs a bit prettier, and bigger
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 5)
plt.rcParams['font.family'] = 'sans-serif'

# %%
requests = pd.read_csv('data/311-service-requests.csv', 
                       dtype ='unicode')

# %% [markdown]
# ### Lets first see how the data looks like

# %%
requests.head()
# Out:
#   Unique Key            Created Date             Closed Date Agency  \
# 0   26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1   26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2   26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3   26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4   26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
#
#                                Agency Name           Complaint Type  \
# 0          New York City Police Department  Noise - Street/Sidewalk
# 1          New York City Police Department          Illegal Parking
# 2          New York City Police Department       Noise - Commercial
# 3          New York City Police Department          Noise - Vehicle
# 4  Department of Health and Mental Hygiene                   Rodent
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk        11432
# ...

# %% [markdown]
# ### Let try to clean the 'Incident zip' first.

# %%
requests['Incident Zip'].unique()
# Out:
# array(['11432', '11378', '10032', '10023', '10027', '11372', '11419',
#        '11417', '10011', '11225', '11218', '10003', '10029', '10466',
#        '11219', '10025', '10310', '11236', nan, '10033', '11216', '10016',
#        '10305', '10312', '10026', '10309', '10036', '11433', '11235',
#        '11213', '11379', '11101', '10014', '11231', '11234', '10457',
#        '10459', '10465', '11207', '10002', '10034', '11233', '10453',
#        '10456', '10469', '11374', '11221', '11421', '11215', '10007',
#        '10019', '11205', '11418', '11369', '11249', '10005', '10009',
#        '11211', '11412', '10458', '11229', '10065', '10030', '11222',
#        '10024', '10013', '11420', '11365', '10012', '11214', '11212',
#        '10022', '11232', '11040', '11226', '10281', '11102', '11208',
#        '10001', '10472', '11414', '11223', '10040', '11220', '11373',
#        '11203', '11691', '11356', '10017', '10452', '10280', '11217',
# ...

# %% [markdown]
# ### There seems to be different versions that needs to be cleaned, like no clue, more than 5 digit zip etc

# %%
# Theres one such zip which is written as no clue

requests['Incident Zip'].str.contains('NO CLUE').sum()
# Out:
# 1

# %%
# two zips with all 0

requests['Incident Zip'].str.contains('00000').sum()
# Out:
# 2

# %% [markdown]
# #### Lets again read the csv and try to exclude such problems from the beginning

# %%
requests = pd.read_csv('data/311-service-requests.csv', 
                       index_col='Unique Key', 
                       dtype = {'Incident Zip': str}, 
                      na_values= ['NO CLUE', '00000'])

# %%
requests.head()
# Out:
#                       Created Date             Closed Date Agency  \
# Unique Key
# 26589651    10/31/2013 02:08:41 AM                     NaN   NYPD
# 26593698    10/31/2013 02:01:04 AM                     NaN   NYPD
# 26594139    10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 26595721    10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 26590930    10/31/2013 01:53:44 AM                     NaN  DOHMH
#
#                                         Agency Name           Complaint Type  \
# Unique Key
# 26589651            New York City Police Department  Noise - Street/Sidewalk
# 26593698            New York City Police Department          Illegal Parking
# 26594139            New York City Police Department       Noise - Commercial
# 26595721            New York City Police Department          Noise - Vehicle
# 26590930    Department of Health and Mental Hygiene                   Rodent
#
#                               Descriptor        Location Type Incident Zip  \
# ...

# %%
# Zipcodes with a hyphen in between

requests['Incident Zip'].str.contains('-').sum()
# Out:
# 5

# %%
# To obtain those five zips

row_with_dashes = requests['Incident Zip'].str.contains('-').fillna(False)

# %%
requests.reset_index()
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 0         26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1         26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2         26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3         26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4         26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
# ...            ...                     ...                     ...    ...
# 111064    26426013  10/04/2013 12:01:13 AM  10/07/2013 04:07:16 PM    DPR
# 111065    26428083  10/04/2013 12:01:05 AM  10/04/2013 02:13:50 AM   NYPD
# 111066    26428987  10/04/2013 12:00:45 AM  10/04/2013 01:25:01 AM   NYPD
# 111067    26426115  10/04/2013 12:00:28 AM  10/04/2013 04:17:32 AM   NYPD
# 111068    26428033  10/04/2013 12:00:10 AM  10/04/2013 01:20:52 AM   NYPD
#
#                                     Agency Name           Complaint Type  \
# ...

# %%
# If more than five digit zips are invalid then simply replacing 
# them with na values woked the below way

#requests['Incident Zip'][rows_with_dashes] = np.nan

# But if we do not wish to remove the zips entirely then follow the next cel
requests[row_with_dashes]
# Out:
#                       Created Date             Closed Date Agency  \
# Unique Key
# 26550551    10/24/2013 06:16:34 PM                     NaN    DCA
# 26548831    10/24/2013 09:35:10 AM                     NaN    DCA
# 26488417    10/15/2013 03:40:33 PM                     NaN    TLC
# 26468296    10/10/2013 12:36:43 PM  10/26/2013 01:07:07 AM    DCA
# 26461137    10/09/2013 05:23:46 PM  10/25/2013 01:06:41 AM    DCA
#
#                                Agency Name      Complaint Type  \
# Unique Key
# 26550551    Department of Consumer Affairs  Consumer Complaint
# 26548831    Department of Consumer Affairs  Consumer Complaint
# 26488417     Taxi and Limousine Commission      Taxi Complaint
# 26468296    Department of Consumer Affairs  Consumer Complaint
# 26461137    Department of Consumer Affairs  Consumer Complaint
#
#                    Descriptor Location Type Incident Zip  \
# Unique Key
# 26550551    False Advertising           NaN   77092-2016
# ...

# %%
long_zip_codes = requests['Incident Zip'].str.len() > 5
long_zip_codes.sum()

# total 6 long zipcodes are there
# Out:
# 6

# %%
# All the zips are truncuted to 5 digits

requests['Incident Zip'] = requests['Incident Zip'].str.slice(0,5)

# %%
# All the 00000s are removed ny nan

zero_zips = requests['Incident Zip'] == '00000'
requests.loc[zero_zips, 'Incident Zip'] = np.nan

# %% [markdown]
# ### Lets check the unique zips

# %%
requests['Incident Zip'].unique()
# Out:
# array(['11432', '11378', '10032', '10023', '10027', '11372', '11419',
#        '11417', '10011', '11225', '11218', '10003', '10029', '10466',
#        '11219', '10025', '10310', '11236', nan, '10033', '11216', '10016',
#        '10305', '10312', '10026', '10309', '10036', '11433', '11235',
#        '11213', '11379', '11101', '10014', '11231', '11234', '10457',
#        '10459', '10465', '11207', '10002', '10034', '11233', '10453',
#        '10456', '10469', '11374', '11221', '11421', '11215', '10007',
#        '10019', '11205', '11418', '11369', '11249', '10005', '10009',
#        '11211', '11412', '10458', '11229', '10065', '10030', '11222',
#        '10024', '10013', '11420', '11365', '10012', '11214', '11212',
#        '10022', '11232', '11040', '11226', '10281', '11102', '11208',
#        '10001', '10472', '11414', '11223', '10040', '11220', '11373',
#        '11203', '11691', '11356', '10017', '10452', '10280', '11217',
# ...

# %%
zips = requests['Incident Zip']
is_close = zips.str.startswith('0') | zips.str.startswith('1')
is_far = ~(is_close) & zips.notnull()

# %%
zips[is_far]
# Out:
# Unique Key
# 26575658    77056
# 26578251    70711
# 26550551    77092
# 26548831    55164
# 26528948    90010
# 26524220    23541
# 26511466    92123
# 26487425    92123
# 26489328    23502
# 26489268    61702
# 26468296    29616
# 26461137    35209
# 26459244    41042
# Name: Incident Zip, dtype: object

# %%
requests[is_far][['Incident Zip', 'Descriptor', 'City']].sort_values('Incident Zip')
# Out:
#            Incident Zip         Descriptor         City
# Unique Key
# 26489328          23502         Harassment      NORFOLK
# 26524220          23541         Harassment      NORFOLK
# 26468296          29616      Debt Not Owed   GREENVILLE
# 26461137          35209         Harassment   BIRMINGHAM
# 26459244          41042         Harassment     FLORENCE
# 26548831          55164         Harassment     ST. PAUL
# 26489268          61702    Billing Dispute   BLOOMIGTON
# 26578251          70711   Contract Dispute      CLIFTON
# 26575658          77056      Debt Not Owed      HOUSTON
# 26550551          77092  False Advertising      HOUSTON
# 26528948          90010    Billing Dispute  LOS ANGELES
# 26511466          92123         Harassment    SAN DIEGO
# 26487425          92123    Billing Dispute    SAN DIEGO

# %%
requests['City'].str.upper().value_counts()
# Out:
# BROOKLYN         31662
# NEW YORK         22664
# BRONX            18438
# STATEN ISLAND     4766
# JAMAICA           2246
#                  ...
# LOS ANGELES          1
# GREENVILLE           1
# NEW YOR              1
# BRIDGE  WATER        1
# MINEOLA              1
# Name: City, Length: 100, dtype: int64

# %% [markdown]
# ### Summing all up as a function

# %%
def fix_zip_codes(zips):
    # Truncate everything to length 5 
    zips = zips.str.slice(0, 5)
    
    # Set 00000 zip codes to nan
    zero_zips = zips == '00000'
    zips[zero_zips] = np.nan
    
    return zips

# %%
requests['Incident Zip'] = fix_zip_codes(requests['Incident Zip'])

# %%
requests['Incident Zip'].unique()
# Out:
# array(['11432', '11378', '10032', '10023', '10027', '11372', '11419',
#        '11417', '10011', '11225', '11218', '10003', '10029', '10466',
#        '11219', '10025', '10310', '11236', nan, '10033', '11216', '10016',
#        '10305', '10312', '10026', '10309', '10036', '11433', '11235',
#        '11213', '11379', '11101', '10014', '11231', '11234', '10457',
#        '10459', '10465', '11207', '10002', '10034', '11233', '10453',
#        '10456', '10469', '11374', '11221', '11421', '11215', '10007',
#        '10019', '11205', '11418', '11369', '11249', '10005', '10009',
#        '11211', '11412', '10458', '11229', '10065', '10030', '11222',
#        '10024', '10013', '11420', '11365', '10012', '11214', '11212',
#        '10022', '11232', '11040', '11226', '10281', '11102', '11208',
#        '10001', '10472', '11414', '11223', '10040', '11220', '11373',
#        '11203', '11691', '11356', '10017', '10452', '10280', '11217',
# ...

# %% [markdown]
# # Parsing unique time stamps in pandas

# %%
# Read it, and remove the last row
popcon = pd.read_csv('data/popularity-contest', sep=' ', )[:-1]
popcon.columns = ['atime', 'ctime', 'package-name', 'mru-program', 'tag']

# %%
popcon.head()
# Out:
#         atime       ctime  package-name  \
# 0  1387295797  1367633260     perl-base
# 1  1387295796  1354370480         login
# 2  1387295743  1354341275    libtalloc2
# 3  1387295743  1387224204  libwbclient0
# 4  1387295742  1354341253   libselinux1
#
#                                     mru-program             tag
# 0                                 /usr/bin/perl             NaN
# 1                                       /bin/su             NaN
# 2  /usr/lib/x86_64-linux-gnu/libtalloc.so.2.0.7             NaN
# 3    /usr/lib/x86_64-linux-gnu/libwbclient.so.0  <RECENT-CTIME>
# 4         /lib/x86_64-linux-gnu/libselinux.so.1             NaN

# %%
popcon.dtypes
# Out:
# atime           object
# ctime           object
# package-name    object
# mru-program     object
# tag             object
# dtype: object

# %% [markdown]
# The magical part about parsing timestamps in pandas is that numpy datetimes are already stored as Unix timestamps. So all we need to do is tell pandas that these integers are actually datetimes -- it doesn't need to do any conversion at all.
#
# We need to convert these to ints to start:

# %%
#First convert it into time stamps

popcon['atime'] = popcon['atime'].astype(int)
popcon['ctime'] = popcon['ctime'].astype(int)

# %%
popcon['atime'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# Every numpy array and pandas series has a dtype -- this is usually int64, float64, or object. Some of the time types available are datetime64[s], datetime64[ms], and datetime64[us]. There are also timedelta types, similarly.
#
# We can use the pd.to_datetime function to convert our integer timestamps into datetimes. This is a constant-time operation -- we're not actually changing any of the data, just how pandas thinks about it.

# %%
# if it is not provided the unit, it wont take the correct format

popcon['atime'] = pd.to_datetime(popcon['atime'], unit='s')
popcon['ctime'] = pd.to_datetime(popcon['ctime'], unit='s')

# %%
popcon['atime'].dtype
# Out:
# dtype('<M8[ns]')

# %%
popcon.head()
# Out:
#                 atime               ctime  package-name  \
# 0 2013-12-17 15:56:37 2013-05-04 02:07:40     perl-base
# 1 2013-12-17 15:56:36 2012-12-01 14:01:20         login
# 2 2013-12-17 15:55:43 2012-12-01 05:54:35    libtalloc2
# 3 2013-12-17 15:55:43 2013-12-16 20:03:24  libwbclient0
# 4 2013-12-17 15:55:42 2012-12-01 05:54:13   libselinux1
#
#                                     mru-program             tag
# 0                                 /usr/bin/perl             NaN
# 1                                       /bin/su             NaN
# 2  /usr/lib/x86_64-linux-gnu/libtalloc.so.2.0.7             NaN
# 3    /usr/lib/x86_64-linux-gnu/libwbclient.so.0  <RECENT-CTIME>
# 4         /lib/x86_64-linux-gnu/libselinux.so.1             NaN

# %% [markdown]
# First, I want to get rid of everything with timestamp 0. Notice how we can just use a string in this comparison, even though it's actually a timestamp on the inside? That is because pandas is amazing.

# %%
popcon = popcon[popcon['atime'] > '1970-01-01']

# %%
nonlibraries = popcon[~popcon['package-name'].str.contains('lib')]

# %%
nonlibraries.sort_values('ctime', ascending=False).head()
# Out:
#                   atime               ctime               package-name  \
# 57  2013-12-17 04:55:39 2013-12-17 04:55:42                        ddd
# 450 2013-12-16 20:03:20 2013-12-16 20:05:13                     nodejs
# 454 2013-12-16 20:03:20 2013-12-16 20:05:04  switchboard-plug-keyboard
# 445 2013-12-16 20:03:20 2013-12-16 20:05:04      thunderbird-locale-en
# 396 2013-12-16 20:08:27 2013-12-16 20:05:03            software-center
#
#                                            mru-program             tag
# 57                                        /usr/bin/ddd  <RECENT-CTIME>
# 450                                       /usr/bin/npm  <RECENT-CTIME>
# 454       /usr/lib/plugs/pantheon/keyboard/options.txt  <RECENT-CTIME>
# 445  /usr/lib/thunderbird-addons/extensions/langpac...  <RECENT-CTIME>
# 396                   /usr/sbin/update-software-center  <RECENT-CTIME>

# %% [markdown]
# Okay, cool, it says that I I installed ddd recently. And postgresql! I remember installing those things. Neat.
#
# The whole message here is that if you have a timestamp in seconds or milliseconds or nanoseconds, then you can just "cast" it to a 'datetime64 [the-right-thing]' and pandas/numpy will take care of the rest.
