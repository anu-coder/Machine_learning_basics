# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# using R style for matplotlib
plt.style.use('ggplot')

# %% [markdown]
# ###  We are using data [Nyc open data](https://nycopendata.socrata.com/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9)

# %%
complaints = pd.read_csv('data/311-service-requests.csv', dtype = 'unicode')

# %%
complaints.head()
# Out:
#   Unique Key            Created Date             Closed Date Agency  \
# 0   26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1   26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2   26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3   26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4   26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
#
#                                Agency Name           Complaint Type  \
# 0          New York City Police Department  Noise - Street/Sidewalk
# 1          New York City Police Department          Illegal Parking
# 2          New York City Police Department       Noise - Commercial
# 3          New York City Police Department          Noise - Vehicle
# 4  Department of Health and Mental Hygiene                   Rodent
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk        11432
# ...

# %%
complaints.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Action Updated Date', 'Community Board', 'Borough',
#        'X Coordinate (State Plane)', 'Y Coordinate (State Plane)',
#        'Park Facility Name', 'Park Borough', 'School Name', 'School Number',
#        'School Region', 'School Code', 'School Phone Number', 'School Address',
#        'School City', 'School State', 'School Zip', 'School Not Found',
#        'School or Citywide Complaint', 'Vehicle Type', 'Taxi Company Borough',
#        'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
# ...

# %%
complaints.dtypes
# Out:
# Unique Key                        object
# Created Date                      object
# Closed Date                       object
# Agency                            object
# Agency Name                       object
# Complaint Type                    object
# Descriptor                        object
# Location Type                     object
# Incident Zip                      object
# Incident Address                  object
# Street Name                       object
# Cross Street 1                    object
# Cross Street 2                    object
# Intersection Street 1             object
# Intersection Street 2             object
# Address Type                      object
# City                              object
# Landmark                          object
# Facility Type                     object
# Status                            object
# Due Date                          object
# Resolution Action Updated Date    object
# Community Board                   object
# ...

# %%
complaints['Complaint Type']
# Out:
# 0         Noise - Street/Sidewalk
# 1                 Illegal Parking
# 2              Noise - Commercial
# 3                 Noise - Vehicle
# 4                          Rodent
#                    ...
# 111064    Maintenance or Facility
# 111065            Illegal Parking
# 111066    Noise - Street/Sidewalk
# 111067         Noise - Commercial
# 111068           Blocked Driveway
# Name: Complaint Type, Length: 111069, dtype: object

# %% [markdown]
# ### To obtain the first five rows of a dataframe
#
# * Use df[:5], to get from 2 to 7 rows : df[2:7], excludes 7

# %%
complaints[2:7]
# Out:
#   Unique Key            Created Date             Closed Date Agency  \
# 2   26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3   26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4   26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
# 5   26592370  10/31/2013 01:46:52 AM                     NaN   NYPD
# 6   26595682  10/31/2013 01:46:40 AM                     NaN   NYPD
#
#                                Agency Name      Complaint Type  \
# 2          New York City Police Department  Noise - Commercial
# 3          New York City Police Department     Noise - Vehicle
# 4  Department of Health and Mental Hygiene              Rodent
# 5          New York City Police Department  Noise - Commercial
# 6          New York City Police Department    Blocked Driveway
#
#                      Descriptor        Location Type Incident Zip  \
# 2              Loud Music/Party  Club/Bar/Restaurant        10032
# ...

# %% [markdown]
# ### To obtain certain rows of a particular column

# %%
complaints['Unique Key'][:5]
# Out:
# 0    26589651
# 1    26593698
# 2    26594139
# 3    26595721
# 4    26590930
# Name: Unique Key, dtype: object

# %% [markdown]
# ### Selecting multiple columns

# %%
complaints[['Unique Key', 'Borough']]
# Out:
#        Unique Key    Borough
# 0        26589651     QUEENS
# 1        26593698     QUEENS
# 2        26594139  MANHATTAN
# 3        26595721  MANHATTAN
# 4        26590930  MANHATTAN
# ...           ...        ...
# 111064   26426013   BROOKLYN
# 111065   26428083     QUEENS
# 111066   26428987  MANHATTAN
# 111067   26426115   BROOKLYN
# 111068   26428033   BROOKLYN
#
# [111069 rows x 2 columns]

# %% [markdown]
# ### 10-15 rows of this two above columns

# %%
complaints[['Unique Key','Borough']][10:15]
# Out:
#    Unique Key    Borough
# 10   26595176   BROOKLYN
# 11   26591982  MANHATTAN
# 12   26594169  MANHATTAN
# 13   26594391      BRONX
# 14   26590917   BROOKLYN

# %%
complaint_counts = complaints['Complaint Type'].value_counts()

# %%
complaint_counts[:10]
# Out:
# HEATING                   14200
# GENERAL CONSTRUCTION       7471
# Street Light Condition     7117
# DOF Literature Request     5797
# PLUMBING                   5373
# PAINT - PLASTER            5149
# Blocked Driveway           4590
# NONCONST                   3998
# Street Condition           3473
# Illegal Parking            3343
# Name: Complaint Type, dtype: int64

# %%
complaint_counts[:10].plot(kind = 'bar', color = 'blue')

# %% [markdown]
# ### Learning proper querying
#
# * find out only the noise related complaints

# %%
# All the noise related complains are:
# 1st way to accomplish

is_noise = [i for i in complaints['Complaint Type'].unique() if 'noise' in i.lower()]
is_noise
noise = np.isin(complaints['Complaint Type'], is_noise)
complaints[noise]
# Out:
#        Unique Key            Created Date             Closed Date Agency  \
# 0        26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 2        26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3        26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 5        26592370  10/31/2013 01:46:52 AM                     NaN   NYPD
# 7        26595195  10/31/2013 01:44:19 AM  10/31/2013 01:58:49 AM   NYPD
# ...           ...                     ...                     ...    ...
# 111059   26429040  10/04/2013 12:04:52 AM  10/04/2013 03:01:04 AM   NYPD
# 111060   26434084  10/04/2013 12:04:00 AM                     NaN    DEP
# 111061   26426164  10/04/2013 12:03:00 AM  10/04/2013 02:14:57 AM   NYPD
# 111066   26428987  10/04/2013 12:00:45 AM  10/04/2013 01:25:01 AM   NYPD
# 111067   26426115  10/04/2013 12:00:28 AM  10/04/2013 04:17:32 AM   NYPD
#
#                                    Agency Name           Complaint Type  \
# ...

# %%
#@nd way to accomplish the task

is_noise = [i for i in complaints['Complaint Type'].unique() 
            if 'noise' in i.lower()]

noise = list()
for i in complaints['Complaint Type']:
    if i in is_noise:
        noise.append(True)
    else:
        noise.append(False)
        
complaints[noise]
# Out:
#        Unique Key            Created Date             Closed Date Agency  \
# 0        26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 2        26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3        26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 5        26592370  10/31/2013 01:46:52 AM                     NaN   NYPD
# 7        26595195  10/31/2013 01:44:19 AM  10/31/2013 01:58:49 AM   NYPD
# ...           ...                     ...                     ...    ...
# 111059   26429040  10/04/2013 12:04:52 AM  10/04/2013 03:01:04 AM   NYPD
# 111060   26434084  10/04/2013 12:04:00 AM                     NaN    DEP
# 111061   26426164  10/04/2013 12:03:00 AM  10/04/2013 02:14:57 AM   NYPD
# 111066   26428987  10/04/2013 12:00:45 AM  10/04/2013 01:25:01 AM   NYPD
# 111067   26426115  10/04/2013 12:00:28 AM  10/04/2013 04:17:32 AM   NYPD
#
#                                    Agency Name           Complaint Type  \
# ...

# %%
# 3rd and the easiest way to accomplish the task is:
# by string vectorising into true false, a two liner

noise = complaints['Complaint Type'].str.lower().str.contains('noise')
complaints[noise]
# Out:
#        Unique Key            Created Date             Closed Date Agency  \
# 0        26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 2        26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3        26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 5        26592370  10/31/2013 01:46:52 AM                     NaN   NYPD
# 7        26595195  10/31/2013 01:44:19 AM  10/31/2013 01:58:49 AM   NYPD
# ...           ...                     ...                     ...    ...
# 111059   26429040  10/04/2013 12:04:52 AM  10/04/2013 03:01:04 AM   NYPD
# 111060   26434084  10/04/2013 12:04:00 AM                     NaN    DEP
# 111061   26426164  10/04/2013 12:03:00 AM  10/04/2013 02:14:57 AM   NYPD
# 111066   26428987  10/04/2013 12:00:45 AM  10/04/2013 01:25:01 AM   NYPD
# 111067   26426115  10/04/2013 12:00:28 AM  10/04/2013 04:17:32 AM   NYPD
#
#                                    Agency Name           Complaint Type  \
# ...

# %% [markdown]
# ### find the "Incident Address" of the noise related complains
#
# Find out later

# %%
pd.DataFrame(complaints[noise]['Incident Address'])
# Out:
#                  Incident Address
# 0                90-03 169 STREET
# 2                   4060 BROADWAY
# 3                  WEST 72 STREET
# 5                       37 AVENUE
# 7       137-09 CROSSBAY BOULEVARD
# ...                           ...
# 111059                99 2 AVENUE
# 111060                        NaN
# 111061             30-09 BROADWAY
# 111066         344 EAST 28 STREET
# 111067       1233 FLATBUSH AVENUE
#
# [8942 rows x 1 columns]

# %%
noise_side = complaints['Complaint Type'] == "Noise - Street/Sidewalk"
in_brooklyn = complaints['Borough'] == "BROOKLYN"
complaints[noise_side & in_brooklyn][:5]
# Out:
#     Unique Key            Created Date             Closed Date Agency  \
# 31    26595564  10/31/2013 12:30:36 AM                     NaN   NYPD
# 49    26595553  10/31/2013 12:05:10 AM  10/31/2013 02:43:43 AM   NYPD
# 109   26594653  10/30/2013 11:26:32 PM  10/31/2013 12:18:54 AM   NYPD
# 236   26591992  10/30/2013 10:02:58 PM  10/30/2013 10:23:20 PM   NYPD
# 370   26594167  10/30/2013 08:38:25 PM  10/30/2013 10:26:28 PM   NYPD
#
#                          Agency Name           Complaint Type  \
# 31   New York City Police Department  Noise - Street/Sidewalk
# 49   New York City Police Department  Noise - Street/Sidewalk
# 109  New York City Police Department  Noise - Street/Sidewalk
# 236  New York City Police Department  Noise - Street/Sidewalk
# 370  New York City Police Department  Noise - Street/Sidewalk
#
#            Descriptor    Location Type Incident Zip    Incident Address  ...  \
# 31   Loud Music/Party  Street/Sidewalk        11236            AVENUE J  ...
# ...

# %%
complaints[noise_side & in_brooklyn][['Complaint Type', 'Borough', 'Created Date', 'Descriptor']][:10]
# Out:
#                Complaint Type   Borough            Created Date  \
# 31    Noise - Street/Sidewalk  BROOKLYN  10/31/2013 12:30:36 AM
# 49    Noise - Street/Sidewalk  BROOKLYN  10/31/2013 12:05:10 AM
# 109   Noise - Street/Sidewalk  BROOKLYN  10/30/2013 11:26:32 PM
# 236   Noise - Street/Sidewalk  BROOKLYN  10/30/2013 10:02:58 PM
# 370   Noise - Street/Sidewalk  BROOKLYN  10/30/2013 08:38:25 PM
# 378   Noise - Street/Sidewalk  BROOKLYN  10/30/2013 08:32:13 PM
# 656   Noise - Street/Sidewalk  BROOKLYN  10/30/2013 06:07:39 PM
# 1251  Noise - Street/Sidewalk  BROOKLYN  10/30/2013 03:04:51 PM
# 5416  Noise - Street/Sidewalk  BROOKLYN  10/29/2013 10:07:02 PM
# 5584  Noise - Street/Sidewalk  BROOKLYN  10/29/2013 08:15:59 PM
#
#             Descriptor
# 31    Loud Music/Party
# 49        Loud Talking
# 109   Loud Music/Party
# 236       Loud Talking
# 370   Loud Music/Party
# 378       Loud Talking
# 656   Loud Music/Party
# 1251      Loud Talking
# 5416      Loud Talking
# ...

# %% [markdown]
# ### A digression on numpy arrays

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
arr = np.array([1,2,3])

# %%
arr !=2
# Out:
# array([ True, False,  True])

# %%
arr[arr!= 2]
# Out:
# array([1, 3])

# %% [markdown]
# ###  Which borough has the highest noise complaint

# %%
is_noise = complaints['Complaint Type'] == "Noise - Street/Sidewalk"
noise_complaints = complaints[is_noise]
noise_complaints['Borough'].value_counts()

# the answer is manhattan
# Out:
# MANHATTAN        917
# BROOKLYN         456
# BRONX            292
# QUEENS           226
# STATEN ISLAND     36
# Unspecified        1
# Name: Borough, dtype: int64

# %%
noise_complaint_counts = noise_complaints['Borough'].value_counts()
complaint_counts = complaints['Borough'].value_counts()
borough= noise_complaint_counts / complaint_counts
borough
# Out:
# BRONX            0.014833
# BROOKLYN         0.013864
# MANHATTAN        0.037755
# QUEENS           0.010143
# STATEN ISLAND    0.007474
# Unspecified      0.000141
# Name: Borough, dtype: float64

# %%
(noise_complaint_counts / complaint_counts.astype(float)).plot(kind='bar', color = 'blue')

# %%
noise_complaint_counts.plot(kind = 'bar')

# %%
fig, axn = plt.subplots(2, 1, figsize = (12, 8))

borough.plot(kind='bar', ax=axn[0])
noise_complaint_counts.plot(kind = 'bar', ax =axn[1])

# %%
borough_merge = pd.concat([borough, noise_complaint_counts], axis = 1).reset_index()
borough_merge.rename(columns={'index': 'borough'}, inplace = True)
borough_merge
# Out:
# C:\Users\Anurima\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#          borough   Borough  Borough
# 0          BRONX  0.014833      292
# 1       BROOKLYN  0.013864      456
# 2      MANHATTAN  0.037755      917
# 3         QUEENS  0.010143      226
# 4  STATEN ISLAND  0.007474       36
# 5    Unspecified  0.000141        1

# %%
fig, axn = plt.subplots(2, 1, figsize = (12, 8))

borough.plot(kind='bar', ax=axn[0])
noise_complaint_counts.plot(kind = 'bar', ax =axn[1])
